# %%
import dotenv

dotenv.load_dotenv()
# Out:
# True

# %%
import datasets as hf

# %%
dataset = hf.load_dataset("qixiaoke/TibHCR", split='train[:10%]')
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
dataset
# Out:
# Dataset({
#     features: ['image', 'label'],
#     num_rows: 14170
# })
